# %%
import pandas as ap

# %%
data=ap.read_csv("C:/New folder/emp_details.csv")
data
# Out:
#    emp_id    name  salary
# 0     100  cravin   72000
# 1     101   rahul   75000
# 2     102  dharan   78000
# 3     103  satish   65000
# 4     104   vijay   63000

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(data["emp_id"],data["salary"],alpha=0.8,color="red",s=100)
plt.xlabel("Empid")
plt.ylabel("salary")
plt.title("EMPDETAILS")
plt.show()
