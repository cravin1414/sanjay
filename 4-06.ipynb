# %%
##python concepts
v=int(input())
f=float(input())
x=input()
k=bool(input())
s=str(input())

##operators
+,-,*,/,+,**,==,// (arithmetic operator)
and , or , not (conditional operator)
##conditional statement
if:
elif:
else:
    for i in range()
    while()
    list=[]
    dict={}
    tuples=()
##break statement -> when the condition is true it use break statement
##continue -> when the condition becomes false it will continue the statement
##pass statement
def class()
##func with arg and re value
##func with no arg and re value
##func with  arg and no re value
##func with no arg and no re value
##lambda=x,y:x+y
##mathematical operation
import math
pow()
sqrt()
pi()
ceil()
floor()
fabs()
##os
import os
getcwd()
listdir()
mkdir()
makedirs()
chdir()
import sys
build in module
specification
import random
random.random
random.shuffle
from itertools import chain
iter()=()
import date and time
.now
.time
.today
.calendar
class sub():
    def sub(self):
try:
except:
finally:
import numpy
shape
size
nbytes
ndim
arrays
arange
import pandas
framework
series
import matplotlib.pyplot
.scatter
.bar
.xlabel
.ylabel
.grid
.plot
.show
assert condition (statement is true) 
assert condition (statement false),write the error
import pytest
from--fn--import --f
code=pytest--f

# %%
a=[10,89,67]
print(min(a))
print(max(a))
print(len(a))
print(sorted(a))
# Out:
# 10
# 89
# 3
# [10, 67, 89]
